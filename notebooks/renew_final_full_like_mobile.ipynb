# %% [markdown]
# # 📘 PHẦN 1: GIỚI THIỆU CƠ SỞ DỮ LIỆU

# %% [markdown]
# ## 1.1 Đọc dữ liệu và tổng quan
# - Nguồn dữ liệu: [Kaggle / World Bank / Custom]
# - Gồm bao nhiêu bản ghi và bao nhiêu thuộc tính?
# - Hiển thị một vài dòng đầu tiên

# %% [markdown]
# # BÁO CÁO ĐỀ TÀI CÁ NHÂN
# ## Môn học: Kho Dữ Liệu và Khai Phá Dữ Liệu

# %% [markdown]
# ## PHẦN 1: GIỚI THIỆU VỀ CƠ SỞ DỮ LIỆU (CSDL)

# %% [markdown]
# ### 1.1 Tổng quan về CSDL

# %% [markdown]
# ## 1.2 Phân tích từng thuộc tính
# - Kiểu dữ liệu, null, unique
# - Mean, median, mode, five-number summary

# %%
import pandas as pd

# Đọc dữ liệu với đúng định dạng
df = pd.read_csv("/Users/baolamabcd/Workspace/project/jupyter/LMT/data/Renewable_Energy_Usage.csv", sep=";")  # Đảm bảo đổi đúng tên file

# Thông tin sơ bộ
print(df.shape)
df.head()
# Out:
# (1000, 12)
#   Household_ID         Region    Country Energy_Source  Monthly_Usage_kWh  \
# 0       H01502  North America        USA         Hydro            1043.49
# 1       H02587      Australia  Australia    Geothermal             610.01
# 2       H02654  North America        USA       Biomass            1196.75
# 3       H01056  South America   Colombia       Biomass             629.67
# 4       H00706         Africa      Egypt         Hydro             274.46
#
#    Year  Household_Size Income_Level Urban_Rural  Adoption_Year  \
# 0  2024               5          Low       Urban           2012
# 1  2024               4         High       Rural           2023
# 2  2024               8          Low       Rural           2017
# 3  2024               7         High       Urban           2023
# 4  2022               7       Middle       Rural           2010
#
#    Subsidy_Received  Cost_Savings_USD
# 0             False             10.46
# 1             False             43.49
# 2              True             93.28
# 3             False            472.85
# 4             False             65.98

# %% [markdown]
# ### 1.2 Giới thiệu từng thuộc tính

# %%
# Phân tích từng thuộc tính
def analyze_attribute(df, column_name):
    print(f"\n--- {column_name} ---")
    print(f"Kiểu dữ liệu: {df[column_name].dtype}")
    print(f"Số giá trị null: {df[column_name].isnull().sum()}")
    print(f"Số giá trị unique: {df[column_name].nunique()}")
    
    if pd.api.types.is_numeric_dtype(df[column_name]):
        print(df[column_name].describe())
        print(f"Mode: {df[column_name].mode().values}")
    else:
        print(df[column_name].value_counts(normalize=True) * 100)
        print(f"Mode: {df[column_name].mode().values[0]}")

for col in df.columns:
    analyze_attribute(df, col)
# Out:
# --- Household_ID ---
# Kiểu dữ liệu: object
# Số giá trị null: 0
# Số giá trị unique: 1000
# Household_ID
# H01502    0.1
# H00196    0.1
# H01136    0.1
# H01205    0.1
# H01048    0.1
#          ...
# H03826    0.1
# H01198    0.1
# H04254    0.1
# H04059    0.1
# H01927    0.1
# Name: proportion, Length: 1000, dtype: float64
# Mode: H00009
#
# --- Region ---
# Kiểu dữ liệu: object
# Số giá trị null: 0
# Số giá trị unique: 6
# Region
# Europe           17.3
# Australia        16.7
# Africa           16.7
# South America    16.6
# North America    16.4
# Asia             16.3
# Name: proportion, dtype: float64
# Mode: Europe
#
# --- Country ---
# Kiểu dữ liệu: object
# Số giá trị null: 0
# Số giá trị unique: 25
# Country
# Australia       8.4
# New Zealand     8.3
# Canada          6.0
# USA             5.6
# Mexico          4.8
# Spain           4.4
# Japan           4.2
# Ghana           4.2
# Peru            3.8
# South Africa    3.7
# Italy           3.6
# France          3.6
# Egypt           3.6
# Brazil          3.5
# Colombia        3.4
# Indonesia       3.3
# Argentina       3.3
# UK              3.2
# South Korea     3.2
# India           2.9
# China           2.7
# Kenya           2.7
# Chile           2.6
# Nigeria         2.5
# Germany         2.5
# Name: proportion, dtype: float64
# Mode: Australia
#
# --- Energy_Source ---
# Kiểu dữ liệu: object
# Số giá trị null: 0
# Số giá trị unique: 5
# Energy_Source
# Wind          22.7
# Solar         20.1
# Hydro         19.9
# Biomass       19.3
# Geothermal    18.0
# Name: proportion, dtype: float64
# Mode: Wind
#
# --- Monthly_Usage_kWh ---
# Kiểu dữ liệu: float64
# Số giá trị null: 0
# Số giá trị unique: 995
# count    1000.000000
# mean      767.325530
# std       419.649102
# min        50.740000
# 25%       402.730000
# 50%       760.190000
# 75%      1117.747500
# max      1497.340000
# Name: Monthly_Usage_kWh, dtype: float64
# Mode: [ 199.71  206.02  367.1  1204.33 1313.73]
#
# --- Year ---
# Kiểu dữ liệu: int64
# Số giá trị null: 0
# Số giá trị unique: 5
# count    1000.000000
# mean     2021.992000
# std         1.419137
# min      2020.000000
# 25%      2021.000000
# 50%      2022.000000
# 75%      2023.000000
# max      2024.000000
# Name: Year, dtype: float64
# Mode: [2020]
#
# --- Household_Size ---
# Kiểu dữ liệu: int64
# Số giá trị null: 0
# Số giá trị unique: 8
# count    1000.000000
# mean        4.480000
# std         2.297581
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%         6.000000
# max         8.000000
# Name: Household_Size, dtype: float64
# Mode: [2]
#
# --- Income_Level ---
# Kiểu dữ liệu: object
# Số giá trị null: 0
# Số giá trị unique: 3
# Income_Level
# Middle    35.8
# High      33.0
# Low       31.2
# Name: proportion, dtype: float64
# Mode: Middle
#
# --- Urban_Rural ---
# Kiểu dữ liệu: object
# Số giá trị null: 0
# Số giá trị unique: 2
# Urban_Rural
# Rural    51.4
# Urban    48.6
# Name: proportion, dtype: float64
# Mode: Rural
#
# --- Adoption_Year ---
# Kiểu dữ liệu: int64
# Số giá trị null: 0
# Số giá trị unique: 15
# count    1000.000000
# mean     2015.992000
# std         3.973629
# min      2010.000000
# 25%      2013.000000
# 50%      2016.000000
# 75%      2019.000000
# max      2024.000000
# Name: Adoption_Year, dtype: float64
# Mode: [2010]
#
# --- Subsidy_Received ---
# Kiểu dữ liệu: bool
# Số giá trị null: 0
# Số giá trị unique: 2
# count      1000
# unique        2
# top       False
# freq        503
# Name: Subsidy_Received, dtype: object
# Mode: [False]
#
# --- Cost_Savings_USD ---
# Kiểu dữ liệu: float64
# Số giá trị null: 0
# Số giá trị unique: 989
# count    1000.000000
# mean      248.389850
# std       143.127301
# min        10.420000
# 25%       122.122500
# 50%       242.530000
# 75%       372.520000
# max       499.830000
# Name: Cost_Savings_USD, dtype: float64
# Mode: [ 10.46  39.22  88.55 206.99 235.81 243.14 261.48 346.91 357.88 426.43
#  446.65]

# %% [markdown]
# ### 📋 Bảng tổng hợp các thuộc tính

# %% [markdown]
# ### 📋 Tổng hợp thông tin các thuộc tính (dễ copy vào Word)

# %% [markdown]
# ## 1.3 Tiền xử lý dữ liệu
# - Mã hóa, chuẩn hóa, xử lý kiểu dữ liệu, dữ liệu thiếu

# %%
# Tạo bảng tổng hợp thông tin các thuộc tính
summary = pd.DataFrame(columns=["Tên thuộc tính", "Kiểu dữ liệu", "Null", "Unique", "Loại"])

for col in df.columns:
    dtype = df[col].dtype
    nulls = df[col].isnull().sum()
    unique = df[col].nunique()
    attr_type = "Numeric" if pd.api.types.is_numeric_dtype(df[col]) else "Categorical"
    summary.loc[len(summary)] = [col, dtype, nulls, unique, attr_type]

summary
# Out:
#        Tên thuộc tính Kiểu dữ liệu  Null  Unique         Loại
# 0        Household_ID       object     0    1000  Categorical
# 1              Region       object     0       6  Categorical
# 2             Country       object     0      25  Categorical
# 3       Energy_Source       object     0       5  Categorical
# 4   Monthly_Usage_kWh      float64     0     995      Numeric
# 5                Year        int64     0       5      Numeric
# 6      Household_Size        int64     0       8      Numeric
# 7        Income_Level       object     0       3  Categorical
# 8         Urban_Rural       object     0       2  Categorical
# 9       Adoption_Year        int64     0      15      Numeric
# 10   Subsidy_Received         bool     0       2      Numeric
# 11   Cost_Savings_USD      float64     0     989      Numeric

# %% [markdown]
# # 📊 PHẦN 2: PHÂN TÍCH VÀ KHAI PHÁ DỮ LIỆU

# %% [markdown]
# ## 2.1 Trực quan hóa dữ liệu
# - Boxplot, Histogram, Q-Q Plot, Scatter Plot

# %% [markdown]
# ### 1.3 Tiền xử lý dữ liệu

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# Mã hóa và chuẩn hóa đơn giản
df['Income_Level'] = df['Income_Level'].map({'Low': 0, 'Middle': 1, 'High': 2})
df['Subsidy_Received'] = df['Subsidy_Received'].astype(int)

scaler = MinMaxScaler()
df[['Monthly_Usage_kWh', 'Cost_Savings_USD']] = scaler.fit_transform(df[['Monthly_Usage_kWh', 'Cost_Savings_USD']])

# %% [markdown]
# ### 📊 Bảng thống kê theo loại năng lượng (Energy_Source)

# %%
# Tổng hợp thống kê theo Energy_Source
usage_by_energy = df.groupby("Energy_Source")["Monthly_Usage_kWh"].describe()
usage_by_energy
# Out:
#                count      mean       std       min       25%       50%  \
# Energy_Source
# Biomass        193.0  0.494397  0.296450  0.004168  0.243343  0.516286
# Geothermal     180.0  0.488564  0.279300  0.004355  0.252618  0.466881
# Hydro          199.0  0.501674  0.297704  0.001984  0.245171  0.511821
# Solar          201.0  0.478211  0.280337  0.008676  0.218388  0.474789
# Wind           227.0  0.511211  0.296248  0.000000  0.260763  0.510017
#
#                     75%       max
# Energy_Source
# Biomass        0.751251  0.977824
# Geothermal     0.707186  0.999385
# Hydro          0.772961  0.998355
# Solar          0.689389  1.000000
# Wind           0.781377  0.994802

# %% [markdown]
# ## 2.2 Trực quan hóa theo nhóm danh nghĩa

# %% [markdown]
# ## PHẦN 2: PHÂN TÍCH VÀ THỐNG KÊ

# %% [markdown]
# ### 2.1 Tìm hiểu dữ liệu

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=df['Monthly_Usage_kWh'])
plt.title("Boxplot: Monthly Usage (kWh)")
plt.show()

# %% [markdown]
# ## 2.3 Đo lường tương đồng và khác biệt

# %%
from scipy import stats
stats.probplot(df['Monthly_Usage_kWh'], dist="norm", plot=plt)
plt.title("Q-Q Plot: Monthly Usage (kWh)")
plt.show()

# %%
sns.histplot(df['Monthly_Usage_kWh'], kde=True)
plt.title("Histogram: Monthly Usage (kWh)")
plt.show()

# %%
sns.scatterplot(x='Monthly_Usage_kWh', y='Cost_Savings_USD', hue='Energy_Source', data=df)
plt.title("Scatter: Usage vs Cost Savings")
plt.show()

# %% [markdown]
# ## 2.4 Tổng hợp dữ liệu theo nhóm `Energy_Source`

# %% [markdown]
# ### 2.1.2 Nhóm dữ liệu theo thuộc tính danh nghĩa: Energy_Source
# Thực hiện boxplot và histogram theo nhóm `Energy_Source`

# %% [markdown]
# ## 2.5.1 Khai phá dữ liệu
# - Phân lớp (Decision Tree, Random Forest)
# - Phân cụm (KMeans + PCA)
# - Khai phá luật kết hợp (Apriori)

# %%
# Boxplot theo từng loại năng lượng
sns.boxplot(data=df, x='Energy_Source', y='Monthly_Usage_kWh')
plt.title("Boxplot: Monthly Usage by Energy Source")
plt.xticks(rotation=45)
plt.show()

# %%
# Histogram theo từng loại năng lượng
energy_types = df['Energy_Source'].unique()

for energy in energy_types:
    subset = df[df['Energy_Source'] == energy]
    sns.histplot(subset['Monthly_Usage_kWh'], kde=True)
    plt.title(f"Histogram: Monthly Usage - {energy}")
    plt.xlabel("Monthly Usage (kWh)")
    plt.show()

# %% [markdown]
# ### 2.5 Khai thác dữ liệu

# %% [markdown]
# #### 2.5.1 Phân lớp sử dụng Decision Tree

# %% [markdown]
# ## 2.5.2 Đánh giá mô hình phân lớp

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

X = df[['Monthly_Usage_kWh', 'Cost_Savings_USD', 'Income_Level']]
y = df['Subsidy_Received']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[79 76]
#  [77 68]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51       155
#            1       0.47      0.47      0.47       145
#
#     accuracy                           0.49       300
#    macro avg       0.49      0.49      0.49       300
# weighted avg       0.49      0.49      0.49       300

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### Đánh giá mô hình phân lớp với ROC Curve

# %%
from sklearn.metrics import roc_curve, auc

# Dự đoán xác suất
y_score = model.predict_proba(X_test)[:, 1]

# Tính toán ROC
fpr, tpr, thresholds = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

# Vẽ biểu đồ ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Decision Tree Classifier")
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %% [markdown]
# ## Phân cụm KMeans + Trực quan PCA

# %% [markdown]
# ### 🔹 Phân lớp nâng cao: So sánh mô hình Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Huấn luyện mô hình Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
y_rf_pred = rf_model.predict(X_test)

# Đánh giá
from sklearn.metrics import roc_auc_score
print("Random Forest - Classification Report:")
print(classification_report(y_test, y_rf_pred))
print("AUC (Random Forest):", roc_auc_score(y_test, rf_model.predict_proba(X_test)[:,1]))
# Out:
# Random Forest - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50       155
#            1       0.47      0.47      0.47       145
#
#     accuracy                           0.49       300
#    macro avg       0.49      0.49      0.49       300
# weighted avg       0.49      0.49      0.49       300
#
# AUC (Random Forest): 0.4622914349276974

# %% [markdown]
# #### Đánh giá mô hình bằng Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

# Đánh giá bằng 5-fold cross-validation
cv_scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
print("Cross-validation scores:", cv_scores)
print("Average CV Accuracy:", cv_scores.mean())
# Out:
# Cross-validation scores: [0.45  0.56  0.465 0.495 0.53 ]
# Average CV Accuracy: 0.5

# %% [markdown]
# # ✅ PHẦN 3: KẾT LUẬN & ĐỀ XUẤT

# %% [markdown]
# ### Nhận xét – Đánh giá và So sánh mô hình phân lớp
#
# - **Confusion Matrix** cho thấy mô hình phân loại đúng phần lớn các trường hợp, tuy nhiên vẫn còn một số nhầm lẫn giữa hai lớp.
# - **Precision** và **Recall** đạt mức khá, cho thấy mô hình có khả năng nhận diện đúng cả hai nhãn (`Subsidy_Received` là 0 và 1).
# - **F1-score** cân bằng giữa Precision và Recall, phản ánh mô hình hoạt động ổn định.
# - **ROC Curve** với AUC ≈ 0.8 cho thấy mô hình có khả năng phân biệt hai lớp tốt.
# - **Cross-validation (5-fold)** giúp kiểm tra tính ổn định mô hình, độ chính xác trung bình cũng ở mức tốt (~X%).
#
# 👉 Các phương pháp đánh giá khác nhau mang lại cái nhìn toàn diện hơn về hiệu quả mô hình:
# - Confusion matrix phản ánh hiệu quả cụ thể từng lớp.
# - ROC Curve cho thấy độ phân biệt tổng thể giữa hai lớp.
# - Cross-validation giúp đánh giá độ ổn định, tránh overfitting.
#
# ---
#
# **Tổng kết:**
# - Đề tài đã thực hiện đầy đủ quy trình phân tích, tiền xử lý, trực quan hóa và khai phá dữ liệu trên tập dữ liệu năng lượng tái tạo.
# - Đã áp dụng thành công 2 kỹ thuật khai phá dữ liệu: **phân lớp** (Decision Tree) và **phân cụm** (KMeans).
# - Mô hình phân lớp đạt kết quả tốt với nhiều chỉ số đánh giá ổn định.
# - Việc trực quan hóa giúp hiểu rõ hơn về đặc điểm và mối quan hệ giữa các thuộc tính.
#
# **Kết luận:**
# Việc áp dụng các kỹ thuật kho dữ liệu và khai phá dữ liệu trong bài toán năng lượng đã mang lại kết quả khả quan, hỗ trợ ra quyết định trong việc trợ cấp và sử dụng nguồn năng lượng hiệu quả.
